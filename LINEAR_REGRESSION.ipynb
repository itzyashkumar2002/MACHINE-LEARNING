# %% [markdown]
# **OlD bike price prediction project**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("imported")
# Out:
# imported

# %%
df = pd.read_csv('/content/Used_Bikes (4).csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
## duplicates
df.duplicated().sum()
# Out:
# 25324

# %%
df.shape
# Out:
# (32648, 8)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (7324, 8)

# %% [markdown]
# **missing value **

# %%
 df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
cat_col = df.select_dtypes(include='O')
cat_col.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
num_col = df.select_dtypes(exclude='O')
num_col.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
# bike_price
# feature selection
cat_col.drop(['bike_name','city'],axis=1,inplace=True)

# %%
cat_col.owner.value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
dt = {'First Owner':1,'Second Owner':2,'Third Owner':3,'Fourth Owner Or More':4}
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
cat_col['owner'] = cat_col['owner'].map(dt)  # only single time execute

# %%
cat_col['brand'].nunique()
# Out:
# 23

# %%
brand_list = list(cat_col['brand'].value_counts().keys())
brand_list
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW',
#  'Jawa',
#  'Indian',
#  'MV',
#  'Rajdoot',
#  'LML',
#  'Yezdi',
#  'Ideal']

# %%
# for loop
# dict={}
# j=1
# for i in ls:
#     dict[i]=j
#     j+=1
# print(dict)

# %%
brand_dict = {}
for value,key in enumerate(brand_list,start=1):
    print(key , " >>> ",value)
    brand_dict[key]  = value
# Out:
# Bajaj  >>>  1
# Royal Enfield  >>>  2
# Hero  >>>  3
# Honda  >>>  4
# Yamaha  >>>  5
# TVS  >>>  6
# KTM  >>>  7
# Suzuki  >>>  8
# Harley-Davidson  >>>  9
# Kawasaki  >>>  10
# Hyosung  >>>  11
# Mahindra  >>>  12
# Benelli  >>>  13
# Triumph  >>>  14
# Ducati  >>>  15
# BMW  >>>  16
# Jawa  >>>  17
# Indian  >>>  18
# MV  >>>  19
# Rajdoot  >>>  20
# LML  >>>  21
# Yezdi  >>>  22
# Ideal  >>>  23

# %%
cat_col['brand'] = cat_col['brand'].map(brand_dict)

# %% [markdown]
# **combining two dataframes **

# %%
df2 = pd.concat([cat_col,num_col],axis='columns')
df2.head()
# Out:
#    owner  brand     price  kms_driven  age  power
# 0      1      6   35000.0     17654.0  3.0  110.0
# 1      1      2  119900.0     11000.0  4.0  350.0
# 2      1     14  600000.0       110.0  8.0  675.0
# 3      1      6   65000.0     16329.0  4.0  180.0
# 4      1      5   80000.0     10000.0  3.0  150.0

# %%
df2.isnull().sum()
# Out:
# owner         0
# brand         0
# price         0
# kms_driven    0
# age           0
# power         0
# dtype: int64

# %%
# splitting x and y
x = df2.drop('price',axis='columns')
y = df2[['price']]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7324 rows x 1 columns]

# %%
#### training testing split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test , y_train, y_test = train_test_split(x,y,test_size=0.2)  # 20% testing

# %%
from sklearn.linear_model import LinearRegression   # class

# %%
# object
lnr = LinearRegression()

# %%
x_train.head()
# Out:
#       owner  brand  kms_driven  age  power
# 5893      1      5     78309.0  9.0  150.0
# 2498      3      4     25000.0  8.0  150.0
# 8160      1      3     19000.0  5.0  100.0
# 7702      1      1      2000.0  5.0  220.0
# 5977      1      1     28425.0  8.0  125.0

# %%
# Train
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# LinearRegression()
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org

# %%
## model testing or model evaluation phase
print("Training score : ",lnr.score(x_train,y_train)*100)
print("Testing score : ",lnr.score(x_test,y_test)*100)

# 90% above
# model score ?
# difference between training score and testing not should be more than 5
# model overfite or underfit

# score  ==>  Down  90%
# difference ==>  okay  5 %


# ## overfit model
# Training score == > High
# Testing score  == > Low


# ## Underfit model
# Training score == > Low   73
# Testing score  == > Low/High  85  ,  60

# generailed model
# score high
# differnce not > 5
# underfit

# %%
x_test.shape
# Out:
# (1465, 5)

# %%
### prediction

unseen_bike = [[1,2,14000.0,2.0,410.0]]    # x variables
lnr.predict(unseen_bike)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[178660.77590356]])

# %%
prediction = lnr.predict(x_test)

# %%
y_test['prediction'] = prediction
y_test.head(40)
# Out:
#          price     prediction
# 8340   35000.0   -2169.810898
# 7918   30000.0   10958.897659
# 2806   39000.0   15159.192405
# 3456  121000.0  155845.980184
# 7472   33000.0   56027.705512
# 7372   21000.0    5414.848668
# 3537   34200.0    2054.512707
# 2704   90000.0  133692.845903
# 1256   13500.0   -4016.040298
# 5536   30000.0   55101.578116
# 2310   66200.0  205252.845445
# 722    80000.0   42784.050384
# 2300  950000.0  711989.561770
# 9071   44000.0   13941.307415
# 199    85000.0  113562.205793
# 8375   60000.0   56269.114802
# 4773   35000.0  100912.363872
# 8528   22000.0   -2034.314471
# 6333   32000.0   -2029.182993
# 2821   62000.0   56960.579457
# 5367   80000.0   71412.775761
# 8052   42000.0   -1015.535479
# 847   120000.0  136143.541611
# 1270   60000.0  104422.828419
# 1517   68000.0   98257.864919
# 5065   43000.0   60496.923391
# 2996   56000.0  104767.105062
# 1283   20500.0   34810.857793
# 705   120000.0  135403.671981
# 6583  114000.0  217672.462706
# 9344   80000.0  126318.447322
# 2899   66700.0  104540.260947
# 5210  140000.0  170682.036178
# 5483  120000.0  112427.992287
# 994    30000.0   22153.990187
# 1409   58000.0   10311.985818
# 2160  124999.0  170192.272522
# 7808   20000.0   50967.265421
# 8072   35000.0   46677.256848
# 8399   55000.0   55803.572690

# %%
final_data = pd.concat([x_test,y_test],axis='columns')
final_data.head()

#(actual price - predicted price )  ==> should be low
# Out:
#       owner  brand  kms_driven  age  power     price     prediction
# 8340      1      1     39468.0  9.0  135.0   35000.0   -2169.810898
# 7918      1      1     45322.0  7.0  150.0   30000.0   10958.897659
# 2806      1      1     96611.0  4.0  150.0   39000.0   15159.192405
# 3456      1      1      9650.0  4.0  400.0  121000.0  155845.980184
# 7472      2      5     13007.0  6.0  150.0   33000.0   56027.705512

# %%
lnr # algorithm
# Out:
# LinearRegression()

# %%
ls = ['vashisht', 'vishab','antish','disha']
ls
# Out:
# ['vashisht', 'vishab', 'antish', 'disha']

# %%
import joblib

# %%
joblib.dump(ls,'student_list.lb')     # to save your variable
# Out:
# ['student_list.lb']

# %%
studet_list = joblib.load('student_list.lb')

# %%
studet_list
# Out:
# ['vashisht', 'vishab', 'antish', 'disha']

# %%
# saving model on a local system
joblib.dump(lnr,'regression_model.lb')
# Out:
# ['regression_model.lb']

# %%
final_data.to_csv('prediction_data.csv',index=False)
